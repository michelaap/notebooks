# %% [markdown]
# # Construindo um Classificador Naive Bayes em Python

# %% [markdown]
# Estamos construindo um classificador Naive Bayes com BernoulliNB e MultinomialNB em Python. Não usaremos as funções do Scikit-learn.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.datasets import fetch_20newsgroups
import logging
import sys
from time import time
from math import *
from matplotlib import pyplot as pl
from matplotlib.backends.backend_pdf import PdfPages

# %%
class MyBernClassifier():
  
    def __init__(self, smooth = 1):
        self._smooth = smooth 
        self._feat_prob = []
        self._class_prob = []
        self._Ncls = []
        self._Nfeat = []

    def train(self, X, y):
        print ("Treinando Bernoulli NB...")
        count_each_class = {}
        feature_count = {}
        alpha = self._smooth 
        temp = []
        temp.append(np.unique(y))
        self._Ncls.append(temp[0].size) # Número total de classes
        self._Nfeat.append(X[0].size)  # Número total de features
        
        for i in range(y.size):
            if y[i] in feature_count:
                continue
            else:
                feature_count[y[i]] = [0 for w in range (X[i].size)]
                

        # Conta os atributos para cada classe através do treinamento ou 
        # conta a ocorrência de cada classe através do treinamento
        for i in range (y.size):
            if y[i] in count_each_class:
                count_each_class[y[i]] +=1
            else:
                count_each_class[y[i]] = 1
            for j in  range(X[i].size):
                    feature_count[y[i]][j] += X[i][j]
                    
        # Calcula probabilidades de classe e atributos para cada classe      
        for cls in feature_count:
            
            num = (self._smooth+count_each_class[cls])
            din = (y.size+(self._Ncls[0]*self._smooth))
            self._class_prob.append((num/float(din)))
            ar = np.array([])
            for j in  range(X[i].size):
                
                num = (feature_count[cls][j] + self._smooth)
                din = (count_each_class[cls]+(2*self._smooth))
                ar = np.append(ar,(num/float(din)))
            self._feat_prob.append(ar)
    

    def predict(self, X):
        
        print ("Fazendo Previsões com Bernoulli NB...")
        
        Y_predict = np.array([])

        for i in X:
            neg_log_prob = 0
            minimum_neg_log_prob = 999999999999999
            category = 0  
                
            for cls in range(self._Ncls[0]):
                neg_log_prob = -log(self._class_prob[cls])
                for j in  range(self._Nfeat[0]):  
                    if (i[j])==0:
                        neg_log_prob -= log(1-self._feat_prob[cls][j])
                    else:
                        neg_log_prob -= log(self._feat_prob[cls][j])
                        
                if minimum_neg_log_prob>neg_log_prob:
                    category=cls
                    minimum_neg_log_prob=neg_log_prob
            
            Y_predict=np.append(Y_predict,category)
         
        return Y_predict

# %%
class MyMultinomialBayesClassifier():
    
    def __init__(self, smooth = 1):
        self._smooth = smooth 
        self._feat_prob = []
        self._class_prob = []
        self._class_neg_prob = []
        self._Ncls = []
        self._Nfeat = []

    def train(self, X, y):
        print ("Treinando Multinomial NB...")
        
        count_each_class = {}
        feature_count = {}
      
        for i in range(y.size):
            if y[i] in feature_count:
                continue
            else:
                feature_count[y[i]] = [0 for w in range (X[i].size)]
                
        for i in range (y.size):
            if y[i] in count_each_class:
                count_each_class[y[i]] +=1
            else:
                count_each_class[y[i]] = 1
            for j in  range(X[i].size):
                    feature_count[y[i]][j] += X[i][j]
                
        alpha = self._smooth 
        temp = []
        temp.append(np.unique(y))
        self._Ncls.append(temp[0].size)
        self._Nfeat.append(X[0].size)  
        self._class_prob.append(count_each_class)
        self._feat_prob.append(feature_count)
        
        
    
    def predict(self, X):
        
        print ("Fazendo Previsões com Multinomial NB...")
        
        Y_predict = np.array([])
        
        # Calcula o total de classes para os dados de treino
        total_train_count = 0
        for key in self._class_prob[0]:
            total_train_count += self._class_prob[0][key]
        
        for i in X:
            neg_log_prob = 0
            minimum_neg_log_prob=999999999999999
            category = 0
            
            for cls in self._feat_prob[0]:
                Ny = sum(self._feat_prob[0][cls])
                neg_log_prob = -log((self._class_prob[0][cls]+1)/float(total_train_count+(self._Ncls[0]*self._smooth)))
                for j in  range(self._Nfeat[0]):  
                    if (i[j])==0:
                        continue    
                    for itere in range (i[j]):
                        num = (self._smooth+self._feat_prob[0][cls][j])
                        din = (Ny+(self._Nfeat[0]*self._smooth))
                        neg_log_prob -= log(num/float(din))
                        
                if minimum_neg_log_prob>neg_log_prob:
                    category=cls
                    minimum_neg_log_prob=neg_log_prob
            
            Y_predict=np.append(Y_predict,category)
         
        return Y_predict

# %%
# Define as classes que serão usadas no processo de classificação
categories = [
        'alt.atheism',
        'talk.religion.misc',
        'comp.graphics',
        'sci.space',
]
remove = ('headers', 'footers', 'quotes')

# %%
# Carrega os dados
data_train = fetch_20newsgroups(subset = 'train', categories = categories, shuffle = True, random_state = 42, remove = remove)
data_test = fetch_20newsgroups(subset = 'test', categories = categories, shuffle = True, random_state = 42, remove = remove)
print('Dados Carregados!')
# Out:
# Dados Carregados!

# %%
# Treino e Teste
y_train, y_test = data_train.target, data_test.target

# %%
print("Extraindo as features do dataset de treino usando o count vectorizer")
t0 = time()
# Out:
# Extraindo as features do dataset de treino usando o count vectorizer

# %%
# Binary = true for Bernoulli NB
vectorizer = CountVectorizer(stop_words = 'english', binary = True)
X_train = vectorizer.fit_transform(data_train.data).toarray()
X_test = vectorizer.transform(data_test.data).toarray()
feature_names = vectorizer.get_feature_names()

# %%
# For Bernoulli NB, Binary = true, train for one default smooth value alpha = 1

print ('-------------------------------------------------------------')
print ('Tempo esperado para execução do modelo Bernoulli NB é 180 seg')
ta = time()
alpha = 1
clf = MyBernClassifier(alpha)
clf.train(X_train,y_train)
y_pred = clf.predict(X_test)
tb = time()
print ("Para o modelo Bernoulli NB:  " +'alpha = %f, accuracy = %f' %(alpha, np.mean((y_test - y_pred)==0)))
print ("Tempo total para treinar e prever com o modelo Bernoulli: " + str(tb-ta))
print ('-------------------------------------------------------------')
# Out:
# -------------------------------------------------------------
# Tempo esperado para execução do modelo Bernoulli NB é 180 seg
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Para o modelo Bernoulli NB:  alpha = 1.000000, accuracy = 0.310421
# Tempo total para treinar e prever com o modelo Bernoulli: 122.19876599311829
# -------------------------------------------------------------

# %% [markdown]
# ### Esta célula pode levar horas para ser executada!

# %%
# Bernoulli Naive bayes: Alpha Vs accuracy
acc = []
alp = []

for alpha in [float(j) / 100 for j in range(1, 101, 1)]:
    print ('-----------------------------------------------------------------------------------------------------')
    ta = time()
    clf = MyBernClassifier(alpha)
    clf.train(X_train,y_train)
    y_pred = clf.predict(X_test)
    acc.append(np.mean((y_test-y_pred)==0))
    alp.append(alpha)
    tb = time()
    print ("Tempo de treinamento: " + str(tb-ta) + " acurácia, alpha is: " + str(np.mean((y_test-y_pred)==0)) +","+str(alpha))

# Plotting 
with PdfPages('Bernoulli.pdf') as pdf:
    pl.plot(alp,acc,marker='.', linestyle = '-', color = 'r')
    pl.ylabel('Acurácia',color='g')
    pl.xlabel('Alpha',color='g')
    pl.title('Plot Alpha Vs Acurácia para Bernoulli NB',color = 'r')
    pdf.savefig() 
    pl.close()

# Print
print ("Acurácia máxima do modelo Bernoulli NB is: " + str(max(acc)))
print ("com valor correspondente para alpha de:       " + str(alp[(acc.index(max(acc)))]))
# Out:
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.3264057636261 acurácia, alpha is: 0.30672579453067256,0.01
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 120.94398427009583 acurácia, alpha is: 0.30450849963045085,0.02
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.11940097808838 acurácia, alpha is: 0.30524759793052475,0.03
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.45233106613159 acurácia, alpha is: 0.30450849963045085,0.04
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.02444982528687 acurácia, alpha is: 0.30303030303030304,0.05
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.16889119148254 acurácia, alpha is: 0.30229120473022913,0.06
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.36947131156921 acurácia, alpha is: 0.30229120473022913,0.07
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.88261795043945 acurácia, alpha is: 0.3008130081300813,0.08
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 118.96424102783203 acurácia, alpha is: 0.29933481152993346,0.09
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.21529197692871 acurácia, alpha is: 0.29933481152993346,0.1
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 120.01223182678223 acurácia, alpha is: 0.29637841832963785,0.11
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.52333498001099 acurácia, alpha is: 0.29637841832963785,0.12
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.64982604980469 acurácia, alpha is: 0.29859571322985956,0.13
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.27778697013855 acurácia, alpha is: 0.29711751662971175,0.14
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.28555703163147 acurácia, alpha is: 0.29637841832963785,0.15
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.14312791824341 acurácia, alpha is: 0.29785661492978566,0.16
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.01981592178345 acurácia, alpha is: 0.29711751662971175,0.17
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.47363185882568 acurácia, alpha is: 0.29711751662971175,0.18
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.91379117965698 acurácia, alpha is: 0.29785661492978566,0.19
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.50347590446472 acurácia, alpha is: 0.29933481152993346,0.2
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.71688890457153 acurácia, alpha is: 0.30007390983000737,0.21
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.41682410240173 acurácia, alpha is: 0.3008130081300813,0.22
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 123.18214082717896 acurácia, alpha is: 0.30229120473022913,0.23
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.81437587738037 acurácia, alpha is: 0.30672579453067256,0.24
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.49327421188354 acurácia, alpha is: 0.3074648928307465,0.25
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 120.51845598220825 acurácia, alpha is: 0.3074648928307465,0.26
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 123.08548998832703 acurácia, alpha is: 0.30672579453067256,0.27
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.67216920852661 acurácia, alpha is: 0.3074648928307465,0.28
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 124.30692195892334 acurácia, alpha is: 0.3082039911308204,0.29
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.9715428352356 acurácia, alpha is: 0.3074648928307465,0.3
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 122.69942212104797 acurácia, alpha is: 0.3082039911308204,0.31
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.8161461353302 acurácia, alpha is: 0.30672579453067256,0.32
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 122.32719993591309 acurácia, alpha is: 0.30450849963045085,0.33
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.63513898849487 acurácia, alpha is: 0.30450849963045085,0.34
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.45499014854431 acurácia, alpha is: 0.30598669623059865,0.35
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.42342400550842 acurácia, alpha is: 0.3074648928307465,0.36
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 123.10876607894897 acurácia, alpha is: 0.3089430894308943,0.37
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.66910576820374 acurácia, alpha is: 0.31042128603104213,0.38
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 122.15025997161865 acurácia, alpha is: 0.3089430894308943,0.39
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 122.45748805999756 acurácia, alpha is: 0.31042128603104213,0.4
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 120.2776129245758 acurácia, alpha is: 0.3089430894308943,0.41
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 122.0942177772522 acurácia, alpha is: 0.3089430894308943,0.42
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.90610313415527 acurácia, alpha is: 0.30524759793052475,0.43
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.38214612007141 acurácia, alpha is: 0.30672579453067256,0.44
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 124.77618503570557 acurácia, alpha is: 0.30968218773096823,0.45
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.89673495292664 acurácia, alpha is: 0.31116038433111604,0.46
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 123.93986988067627 acurácia, alpha is: 0.31189948263118994,0.47
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.76683521270752 acurácia, alpha is: 0.31189948263118994,0.48
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 122.17448210716248 acurácia, alpha is: 0.3148558758314856,0.49
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.2012209892273 acurácia, alpha is: 0.3155949741315595,0.5
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.04671001434326 acurácia, alpha is: 0.3155949741315595,0.51
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 118.9481782913208 acurácia, alpha is: 0.3148558758314856,0.52
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.35985398292542 acurácia, alpha is: 0.31411677753141165,0.53
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 120.98639702796936 acurácia, alpha is: 0.31411677753141165,0.54
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 120.9850480556488 acurácia, alpha is: 0.3155949741315595,0.55
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 122.20061111450195 acurácia, alpha is: 0.31411677753141165,0.56
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 122.6094400882721 acurácia, alpha is: 0.31337767923133775,0.57
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.87618803977966 acurácia, alpha is: 0.31411677753141165,0.58
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 120.63389682769775 acurácia, alpha is: 0.3148558758314856,0.59
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 120.17337393760681 acurácia, alpha is: 0.3155949741315595,0.6
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 122.17201399803162 acurácia, alpha is: 0.3148558758314856,0.61
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 122.18732714653015 acurácia, alpha is: 0.31337767923133775,0.62
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.09355592727661 acurácia, alpha is: 0.31263858093126384,0.63
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 122.09412717819214 acurácia, alpha is: 0.3148558758314856,0.64
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 122.5351197719574 acurácia, alpha is: 0.3148558758314856,0.65
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.04955410957336 acurácia, alpha is: 0.31411677753141165,0.66
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.55147576332092 acurácia, alpha is: 0.3148558758314856,0.67
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.0934488773346 acurácia, alpha is: 0.3170731707317073,0.68
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.16955423355103 acurácia, alpha is: 0.31855136733185513,0.69
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 122.13886499404907 acurácia, alpha is: 0.3170731707317073,0.7
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 122.98891806602478 acurácia, alpha is: 0.3170731707317073,0.71
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.76238918304443 acurácia, alpha is: 0.31855136733185513,0.72
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.25049209594727 acurácia, alpha is: 0.31855136733185513,0.73
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.67333006858826 acurácia, alpha is: 0.3178122690317812,0.74
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 120.91357374191284 acurácia, alpha is: 0.31929046563192903,0.75
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 122.04678988456726 acurácia, alpha is: 0.31929046563192903,0.76
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.68623113632202 acurácia, alpha is: 0.31855136733185513,0.77
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.36870884895325 acurácia, alpha is: 0.3170731707317073,0.78
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.90873312950134 acurácia, alpha is: 0.3163340724316334,0.79
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.55166602134705 acurácia, alpha is: 0.3163340724316334,0.8
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 125.63657712936401 acurácia, alpha is: 0.3163340724316334,0.81
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.61760210990906 acurácia, alpha is: 0.3170731707317073,0.82
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 122.51788806915283 acurácia, alpha is: 0.3170731707317073,0.83
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.84876108169556 acurácia, alpha is: 0.3170731707317073,0.84
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.29049706459045 acurácia, alpha is: 0.3170731707317073,0.85
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 123.02547097206116 acurácia, alpha is: 0.3163340724316334,0.86
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 121.2745988368988 acurácia, alpha is: 0.31337767923133775,0.87
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 120.8321840763092 acurácia, alpha is: 0.3148558758314856,0.88
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.02469897270203 acurácia, alpha is: 0.3148558758314856,0.89
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 118.87668991088867 acurácia, alpha is: 0.31411677753141165,0.9
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 118.40462803840637 acurácia, alpha is: 0.31411677753141165,0.91
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.6154727935791 acurácia, alpha is: 0.3163340724316334,0.92
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.39736413955688 acurácia, alpha is: 0.3163340724316334,0.93
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.15643787384033 acurácia, alpha is: 0.3155949741315595,0.94
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.1279878616333 acurácia, alpha is: 0.31411677753141165,0.95
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 120.59028887748718 acurácia, alpha is: 0.31411677753141165,0.96
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 119.2187831401825 acurácia, alpha is: 0.31116038433111604,0.97
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 118.70002174377441 acurácia, alpha is: 0.31116038433111604,0.98
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 118.72720575332642 acurácia, alpha is: 0.31116038433111604,0.99
# -----------------------------------------------------------------------------------------------------
# Treinando Bernoulli NB...
# Fazendo Previsões com Bernoulli NB...
# Tempo de treinamento: 120.55084228515625 acurácia, alpha is: 0.31042128603104213,1.0
# Acurácia máxima do modelo Bernoulli NB is: 0.31929046563192903
# com valor correspondente para alpha de:       0.75

# %%
# Binary = false para Multinomial NB

print ("Extraindo dados com Binary = False para Multinomial NB")
vectorizer = CountVectorizer(stop_words = 'english', binary = False)
X_train = vectorizer.fit_transform(data_train.data).toarray()
X_test = vectorizer.transform(data_test.data).toarray()
feature_names = vectorizer.get_feature_names()

print ('Tempo total esperado para execução do Multinomial NB é 90 seg')
ta = time()
alpha = 1
clf1 = MyMultinomialBayesClassifier(alpha)
clf1.train(X_train,y_train)
y_pred = clf1.predict(X_test)

print ("Para modelo Multinomial NB:  " +'alpha = %f accuracy = %f' %(alpha, np.mean((y_test-y_pred)==0)))
tb = time()
print ("Tempo total para treinar e prever o modelo Multinomial: " + str(tb-ta))
print ('--------------------------------------------------------------------------------------')

# %% [markdown]
# ### Esta célula pode levar horas para ser executada!

# %%
# Multionomial Naive bayes: Alpha Vs accuracy 
acc = []
alp = []

for alpha in [float(j) / 100 for j in range(1, 101, 1)]:
    print ('--------------------------------------------------------------------------------------')
    ta = time()
    clf1 = MyMultinomialBayesClassifier(alpha)
    clf1.train(X_train,y_train)
    y_pred1 = clf1.predict(X_test)
    acc.append(np.mean((y_test-y_pred1)==0))
    alp.append(alpha)
    tb = time()
    print ("Tempo de Treinamento: " + str(tb-ta) + " acurácia, alpha é: " + str(np.mean((y_test-y_pred1)==0)) +","+str(alpha))
    #print ('alpha=%f accuracy = %f' %(alpha, np.mean((y_test-y_pred1)==0)))

# Plotting 
with PdfPages('multinomial.pdf') as pdf:
    pl.plot(alp,acc,marker = '.', linestyle = '-', color = 'r')
    pl.ylabel('Acurácia',color = 'g')
    pl.xlabel('Alpha',color = 'g')
    pl.title('Plot Alpha Vs Acurácia para Multinomial NB',color = 'r')
    pdf.savefig() 
    pl.close()

# Max Accuracy and Corresponding alpha.

print ("Acurácia máxima para o modelo Multinomial NB is: " + str(max(acc)))
print ("com valor correspondente alpha de:       " + str(alp[(acc.index(max(acc)))]))
